# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/salary_cleaned.csv', index_col = None)
df.tail()
# Out:
#        Unnamed: 0            timestamp         company level  \
# 24491       27667  2020-09-30 22:08:32           Apple  ICT4
# 24492       27668  2020-09-30 22:30:24          Slalom     6
# 24493       27669  2020-09-30 22:54:25  General Motors    L8
# 24494       27670  2020-09-30 23:04:34      Albertsons  SE 5
# 24495       27671  2020-09-30 23:16:19          Amazon    L7
#
#                               title  totalyearlycompensation  \
# 24491             Software Engineer                    336.0
# 24492            Solution Architect                    148.0
# 24493  Software Engineering Manager                    245.0
# 24494             Software Engineer                    160.0
# 24495  Software Engineering Manager                    480.0
#
#                 location  yearsofexperience  yearsatcompany  \
# 24491  San Francisco, CA                4.0             4.0
# 24492         Denver, CO                8.0             2.0
# ...

# %%
df['inflation_rate'].iloc[-1]
# Out:
# 0.014
